# %% [markdown]
# # Домашнее задание 3.1: постановка задач глубинного обучения
#
# Цель: научиться формулировать CV/DL-задачу: вход, выход, тип задачи, loss, метрика, baseline и связь с финальным проектом.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 1. Загрузка датасета digits

# %%
digits = load_digits()
X = digits.images
y = digits.target

print("Images:", X.shape)
print("Target:", y.shape)
print("Classes:", np.unique(y))

# %% [markdown]
# ## 2. Визуализация изображений

# %%
fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for ax, image, label in zip(axes.ravel(), X[:10], y[:10]):
    ax.imshow(image, cmap="gray")
    ax.set_title(f"label={label}")
    ax.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Задание 1. Сформулируйте задачу
#
# Заполните переменные ниже.

# %%
task_type = "..."          # например: многоклассовая классификация
input_object = "..."       # что подаётся на вход?
target_object = "..."      # что нужно предсказать?
possible_loss = "..."      # какую loss можно использовать?
main_metric = "..."        # какую метрику можно использовать?

print(task_type, input_object, target_object, possible_loss, main_metric, sep="\n")

# %% [markdown]
# ## 3. Baseline

# %%
X_flat = X.reshape(len(X), -1)

X_train, X_test, y_train, y_test = train_test_split(
    X_flat, y, test_size=0.2, random_state=42, stratify=y
)

baseline = DummyClassifier(strategy="most_frequent")
baseline.fit(X_train, y_train)

y_pred = baseline.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Macro F1:", f1_score(y_test, y_pred, average="macro"))

# %% [markdown]
# ## Задание 2. Объясните baseline
#
# Ответьте:
# 1. Зачем нужен baseline?
# 2. Почему accuracy baseline может быть не нулевой?
# 3. Почему macro F1 у baseline обычно низкий?

# %%
baseline_answer = '''
1. ...
2. ...
3. ...
'''
print(baseline_answer)

# %% [markdown]
# ## 4. Распределение классов

# %%
counts = pd.Series(y).value_counts().sort_index()

plt.figure(figsize=(8, 4))
plt.bar(counts.index.astype(str), counts.values)
plt.title("Class distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

counts

# %% [markdown]
# ## Задание 3. Выберите метрики
#
# Укажите, какие метрики подходят для задачи распознавания цифр и почему.

# %%
metrics_answer = '''
Я бы использовал(а):
1. ...
2. ...
3. ...

Почему:
...
'''
print(metrics_answer)

# %% [markdown]
# ## 5. Confusion matrix baseline

# %%
cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(8, 8))
disp = ConfusionMatrixDisplay(cm, display_labels=digits.target_names)
disp.plot(ax=ax, cmap="Blues", values_format="d")
plt.show()

# %% [markdown]
# ## Задание 4. Определите тип CV-задачи
#
# Заполните словарь. Варианты: classification, regression, object detection, segmentation, generation, inpainting, OCR, VLM/VQA.

# %%
task_types = {
    "Определить, есть ли кошка на изображении": "...",
    "Найти все машины на фото и обвести их рамками": "...",
    "Выделить каждого человека отдельной маской": "...",
    "Убрать объект с фотографии": "...",
    "Сгенерировать изображение по тексту": "...",
    "Ответить на вопрос по изображению": "...",
    "Распознать текст на фото документа": "...",
    "Оценить возраст человека по фото": "..."
}

pd.DataFrame({"task": task_types.keys(), "answer": task_types.values()})

# %% [markdown]
# ## Задание 5. Связь с финальным проектом
#
# Опишите, какие CV/DL-подзадачи есть в агенте для редактирования изображений.

# %%
project_answer = '''
В финальном проекте могут быть такие подзадачи:
1. ...
2. ...
3. ...
4. ...
5. ...
'''
print(project_answer)

# %% [markdown]
# ## Критерии оценки
#
# Всего: 40 баллов.
#
# - формулировка задачи — 10;
# - baseline — 5;
# - метрики — 10;
# - типы CV-задач — 10;
# - связь с финальным проектом — 5.

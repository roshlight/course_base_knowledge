# %% [markdown]
# # Домашнее задание 3.4: Vision Transformer и патчи
#
# Цель: понять, как изображение превращается в последовательность патчей, и собрать toy Vision Transformer.

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device

# %% [markdown]
# ## 1. Синтетическое изображение

# %%
image_size = 224
img = Image.new("RGB", (image_size, image_size), color="white")
draw = ImageDraw.Draw(img)
draw.rectangle([30, 40, 100, 130], fill="red")
draw.ellipse([130, 70, 200, 140], fill="blue")
draw.rectangle([80, 160, 170, 205], fill="green")
img

# %%
def image_to_tensor(img):
    arr = np.array(img).astype(np.float32) / 255.0
    return torch.from_numpy(arr).permute(2, 0, 1)

x = image_to_tensor(img)
x.shape

# %% [markdown]
# ## Задание 1. Реализуйте split_into_patches

# %%
def split_into_patches(image_tensor, patch_size):
    '''
    image_tensor: [C, H, W]
    return: [num_patches, C, patch_size, patch_size]
    '''
    # TODO
    raise NotImplementedError

# patches = split_into_patches(x, 16)
# print(patches.shape)
# assert patches.shape == (196, 3, 16, 16)

# %% [markdown]
# ## 2. Визуализация патчей

# %%
# fig, axes = plt.subplots(4, 8, figsize=(12, 6))
# for ax, patch in zip(axes.ravel(), patches[:32]):
#     ax.imshow(patch.permute(1, 2, 0).numpy())
#     ax.axis("off")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Задание 2. Реализуйте PatchEmbedding через Conv2d

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, in_channels=3, patch_size=16, embed_dim=128):
        super().__init__()
        self.patch_size = patch_size
        # TODO: Conv2d с kernel_size=patch_size и stride=patch_size
        # self.proj = ...

    def forward(self, x):
        '''
        x: [B, C, H, W]
        return: [B, num_patches, embed_dim]
        '''
        # TODO
        raise NotImplementedError

# patch_embed = PatchEmbedding()
# out = patch_embed(x.unsqueeze(0))
# print(out.shape)
# assert out.shape == (1, 196, 128)

# %% [markdown]
# ## Задание 3. Реализуйте MiniViT

# %%
class MiniViT(nn.Module):
    def __init__(self, image_size=224, patch_size=16, num_classes=10, embed_dim=128, num_heads=4, num_layers=2):
        super().__init__()

        self.patch_embed = PatchEmbedding(3, patch_size, embed_dim)
        num_patches = (image_size // patch_size) ** 2

        # TODO: cls_token shape [1, 1, embed_dim]
        # self.cls_token = ...

        # TODO: pos_embed shape [1, num_patches + 1, embed_dim]
        # self.pos_embed = ...

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            dim_feedforward=256,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.head = nn.Linear(embed_dim, num_classes)

    def forward(self, x):
        # TODO:
        # patch embeddings
        # добавить CLS
        # добавить positional embeddings
        # encoder
        # взять CLS и head
        raise NotImplementedError

# model = MiniViT().to(device)
# logits = model(x.unsqueeze(0).to(device))
# print(logits.shape)
# assert logits.shape == (1, 10)

# %% [markdown]
# ## Задание 4. Ответьте на вопросы

# %%
answers = '''
1. Зачем разбивать изображение на патчи?
...
2. Что такое patch embedding?
...
3. Зачем нужен CLS token?
...
4. Зачем positional embeddings?
...
5. Почему attention полезен для CV?
...
'''
print(answers)

# %% [markdown]
# ## Задание 5. Связь с финальным проектом

# %%
project_answer = '''
Трансформеры и VLM полезны в финальном проекте, потому что:
1. ...
2. ...
3. ...

Пример:
...
'''
print(project_answer)

# %% [markdown]
# ## Критерии оценки
#
# Всего: 60 баллов: patches — 15, визуализация — 5, PatchEmbedding — 15, MiniViT — 15, вопросы — 10.
